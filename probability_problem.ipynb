# %%
from scipy.stats import binom

# %% [markdown]
# # question-1

# %%
binom.pmf(n=12,p=0.9,k=10)#exactly
# Out:
# np.float64(0.23012777046599997)

# %%
binom.sf(n=12,p=0.9,k=11)#atleast
# Out:
# np.float64(0.282429536481)

# %%
binom.cdf(n=12,p=0.9,k=9)#fewer
# Out:
# np.float64(0.11086997774499993)

# %% [markdown]
# # question-2

# %%
binom.pmf(n=15,p=0.65,k=12)#exactly
# Out:
# np.float64(0.11096239180419934)

# %%
binom.sf(n=15,p=0.65,k=10)#atleast
# Out:
# np.float64(0.3519434277762673)

# %%
binom.mean(n=15,p=0.65)#expected
# Out:
# np.float64(9.75)

# %% [markdown]
# question-3

# %%
binom.pmf(n=20,p=0.7,k=16)#exactly
# Out:
# np.float64(0.1304209743738704)

# %%
binom.sf(n=20,p=0.7,k=18)#more than
# Out:
# np.float64(0.007637259774199997)

# %%
binom.mean(n=20,p=0.7)#mean
# Out:
# np.float64(14.0)

# %%
binom.var(n=20,p=0.7)#variance
# Out:
# np.float64(4.200000000000001)

# %% [markdown]
# question-4

# %%
binom.pmf(n=10,p=0.4,k=5)#exactly
# Out:
# np.float64(0.20065812479999992)

# %%
binom.sf(n=10,p=0.4,k=7)#atleast
# Out:
# np.float64(0.012294553600000006)

# %%
binom.pmf(n=10,p=0.4,k=0)#no boundaries
# Out:
# np.float64(0.0060466175999999185)

# %% [markdown]
# question-5

# %%
binom.pmf(n=30,p=0.05,k=2)#exactly
# Out:
# np.float64(0.25863673771517404)

# %%
binom.pmf(n=30,p=0.05,k=0)#none defective
# Out:
# np.float64(0.21463876394293752)

# %%
binom.sf(n=30,p=0.05,k=1)#atleast
# Out:
# np.float64(0.44645792456821287)

# %% [markdown]
# question-6

# %%
binom.pmf(n=18,p=0.25,k=6)#exactly
# Out:
# np.float64(0.1435644040466287)

# %%
binom.sf(n=18,p=0.25,k=4)#atleast
# Out:
# np.float64(0.4813306695432402)

# %%
binom.mean(n=18,p=0.25,)#expected
# Out:
# np.float64(4.5)

# %% [markdown]
# question-7

# %%
binom.pmf(n=25,p=0.95,k=24)#exactly
# Out:
# np.float64(0.3649862804234658)

# %%
binom.pmf(n=25,p=0.95,k=25)#all respond successfully
# Out:
# np.float64(0.27738957312183377)

# %%
binom.cdf(n=25,p=0.95,k=23)#fewer
# Out:
# np.float64(0.3576241464547004)

# %% [markdown]
# question-8

# %%
binom.pmf(n=20,p=0.92,k=18)#exactly
# Out:
# np.float64(0.2710906052244336)

# %%
binom.pmf(n=20,p=0.92,k=20)#all test cases pass
# Out:
# np.float64(0.1886933291627967)

# %%
binom.sf(n=20,p=0.92,k=19)#atleast
# Out:
# np.float64(0.18869332916279669)

# %% [markdown]
# question-9

# %%
binom.pmf(n=15,p=0.8,k=12)#exactly
# Out:
# np.float64(0.25013889531904)

# %%
binom.sf(n=15,p=0.8,k=10)#more than
# Out:
# np.float64(0.8357662760632321)

# %%
binom.mean(n=15,p=0.8)#expected
# Out:
# np.float64(12.0)

# %% [markdown]
# question-10

# %%
binom.pmf(n=25,p=0.3,k=8)#exactly
# Out:
# np.float64(0.1650795811315247)

# %%
binom.sf(n=25,p=0.3,k=10)#atleast
# Out:
# np.float64(0.09780001112173187)

# %%
binom.cdf(n=25,p=0.3,k=5)#fewer
# Out:
# np.float64(0.19348844208806493)
