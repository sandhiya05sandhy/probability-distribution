# %%
from scipy.stats import binom

# %%
binom.pmf(n=12,k=10,p=0.6)
# Out:
# np.float64(0.06385228185600002)

# %%
binom.pmf(n=5,k=2,p=0.5)
# Out:
# np.float64(0.31249999999999983)

# %%
binom.pmf(n=5,k=1,p=0.5)
# Out:
# np.float64(0.15624999999999997)

# %%
binom.pmf(n=5,k=0,p=0.5)
# Out:
# np.float64(0.031249999999999976)

# %%
binom.cdf(n=5,k=2,p=0.5)
# Out:
# np.float64(0.5)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
b=np.random.normal(loc=0,scale=1,size=50)
plt.hist(b,bins=20)
plt.title("Normal Distribution")
plt.show()

# %%
plt.boxplot (b,orientation ='horizontal')
plt.title("Normal Distribution")
plt.show()

# %%
sns.histplot(b,kde=True)
plt.title("Normal Distribution")
plt.show()
